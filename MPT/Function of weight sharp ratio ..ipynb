# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from pandas_datareader import data as pdr
import yfinance as yf
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
plt.style.use('seaborn-colorblind')  
# %matplotlib inline

# %%
# This function is for 4 shares  downloaded from yfinance .. facing some error while doing on dataset. but function is dere

# %%
# Create our portfolio of equities
tickers = ['AAPL','FB', 'C', 'DIS']
 
# Download closing prices
data = pdr.get_data_yahoo(tickers, start="2018-01-01", end=dt.date.today())['Close']

# %%
# From the closing prices, calculate periodic returns
returns = data.pct_change()

# Preview the data
data.tail()
print(returns)
# Out:
# Symbols         AAPL        FB         C       DIS
# Date
# 2018-01-02       NaN       NaN       NaN       NaN
# 2018-01-03 -0.000174  0.017914  0.003093  0.004293
# 2018-01-04  0.004645 -0.001841  0.012334 -0.000445
# 2018-01-05  0.011385  0.013671 -0.001324 -0.005435
# 2018-01-08 -0.003714  0.007653 -0.011670 -0.014334
# ...              ...       ...       ...       ...
# 2022-03-25  0.003734  0.010247  0.005672  0.001295
# 2022-03-28  0.005037  0.007979 -0.014452 -0.003019
# 2022-03-29  0.019134  0.028042  0.009836  0.026384
# 2022-03-30 -0.006650 -0.008744 -0.026563 -0.009973
# 2022-03-31 -0.008100 -0.007637 -0.002183 -0.006740
#
# [1070 rows x 4 columns]

# %%
returns = data.pct_change()
returns
# Out:
# Symbols         AAPL        FB         C       DIS
# Date
# 2018-01-02       NaN       NaN       NaN       NaN
# 2018-01-03 -0.000174  0.017914  0.003093  0.004293
# 2018-01-04  0.004645 -0.001841  0.012334 -0.000445
# 2018-01-05  0.011385  0.013671 -0.001324 -0.005435
# 2018-01-08 -0.003714  0.007653 -0.011670 -0.014334
# ...              ...       ...       ...       ...
# 2022-03-25  0.003734  0.010247  0.005672  0.001295
# 2022-03-28  0.005037  0.007979 -0.014452 -0.003019
# 2022-03-29  0.019134  0.028042  0.009836  0.026384
# 2022-03-30 -0.006650 -0.008744 -0.026563 -0.009973
# 2022-03-31 -0.008100 -0.007637 -0.002183 -0.006740
#
# [1070 rows x 4 columns]

# %%
# Define function to calculate returns, volatility
def portfolio_annualized_performance(weights, mean_returns, cov_matrix):
    # Given the avg returns, weights of equities calc. the portfolio return
    returns = np.sum(mean_returns*weights ) *252
    # Standard deviation of portfolio (using dot product against covariance, weights)
    # 252 trading days
    std = np.sqrt(np.dot(weights.T, np.dot(cov_matrix, weights))) * np.sqrt(252)
    return std, returns

# %%
def generate_random_portfolios(num_portfolios, mean_returns, cov_matrix, risk_free_rate,num_assets,df=data):
    # Initialize array of shape 3 x N to store our results, 
    # where N is the number of portfolios we're going to simulate
#     results = np.zeros((3,num_portfolios))
    # Array to store the weights of each equity
    weight_array = []
    portfolioReturns = []  ## empty list for portfolio returns
    portfolioRisk = []  ## empty list for portfolio Risk
    sharpe_ratio = []
    
    for i in range(num_portfolios):
        # Randomly assign floats to our 4 equities
        weights = np.random.random(num_assets)
        # Convert the randomized floats to percentages (summing to 100)
        weights /= np.sum(weights)
        # Add to our portfolio weight array
        weight_array.append(weights)
        # Pull the standard deviation, returns from our function above using 
        # the weights, mean returns generated in this function
        portfolio_std_dev, portfolio_return = portfolio_annualized_performance(weights, mean_returns, cov_matrix)
        portfolioReturns.append(portfolio_return)
        portfolioRisk.append(portfolio_std_dev)
        
        data = {'Returns':portfolioReturns,'Volatility':portfolioRisk}
        
        for counter, symbol in enumerate(df.columns.to_list()):
            data[symbol+'_weight'] = [w[counter] for w in weight_array]
        portfolio = pd.DataFrame(data)
        
        portfolio['Sharpe_Ratio'] = (portfolio['Returns'] - risk_free_rate)/portfolio["Volatility"]
        
        return portfolio
        
        
        
        
#         # Store output
#         results[0,i] = portfolio_std_dev
#         results[1,i] = portfolio_return
#         # Sharpe ratio
#         results[2,i] = (portfolio_return - risk_free_rate) / portfolio_std_dev
#         sharpe_ratio.append(results[2,i]) 
#     return pd.DataFrame(results) ,pd.DataFrame(weight_array),pd.DataFrame(sharpe_ratio) #results

# %%
returns = data.pct_change()
mean_returns = returns.mean()
cov_matrix = returns.cov()
# Number of portfolios to simulate
num_portfolios = 10000
# Risk free rate (used for Sharpe ratio below)
# anchored on treasury bond rates
risk_free_rate = 0.018

# %%
generate_random_portfolios(1000, mean_returns, cov_matrix, risk_free_rate,num_assets=4,df = data)
# Out:
#     Returns  Volatility  AAPL_weight  FB_weight  C_weight  DIS_weight  \
# 0  0.144043    0.275074     0.191872   0.280694  0.210567    0.316867
#
#    Sharpe_Ratio
# 0      0.458213

# %%
def portfolios(df,rf, annual_returns,)
portfolioReturns = []  ## empty list for portfolio returns
portfolioRisk = []  ## empty list for portfolio Risk
stockWeights = []   ## ## empty list for asset weights

num_assets = len(df1.columns) 
num_portfolios = 10000

for portfolio in range(num_portfolios):
    weights = np.random.random(num_assets)
    weights /= np.sum(weights)
# weights.shape #50
# annualReturn.shape #49


    stockWeights.append(weights)
    returns = np.dot(weights, annualReturns) # Returns are the product of individual expected returns of asset and its
                                        # weights
    portfolioReturns.append(returns)
    var = cov.mul(weights, axis=0).mul(weights, axis=1).sum().sum()# Portfolio variance
    sd = np.sqrt(var) # paily standard deviation
    ann_sd = sd*np.sqrt (250) # Annual standard deviation - volatility
    portfolioRisk.append(ann_sd)

data = {'Returns':portfolioReturns,'Volatility':portfolioRisk}

## Selecting minimum variance Portfolio

for counter, symbol in enumerate(df1.columns.to_list()):
    data[symbol+'_weight'] = [w[counter] for w in stockWeights]
portfolio = pd.DataFrame(data)

rf = 0.06122
portfolio['Sharpe_Ratio'] = (portfolio['Returns'] - rf)/portfolio["Volatility"]

portfolio
